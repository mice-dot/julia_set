# %%
# %load_ext memory_profiler

# %%
# %memit [i*i for i in range(100000)]
# Out:
# peak memory: 96.14 MiB, increment: 0.23 MiB

# %%
# %%memit l = []
# for i in range(100000):
#     l.append(i * 2)
# Out:
# peak memory: 97.94 MiB, increment: 2.58 MiB

# %%
# %%memit l = []
# for i in range(100_000):
#     l.append(i * 2)
# Out:
# peak memory: 98.70 MiB, increment: 1.75 MiB

# %%
# %memit l = []
for i in range(100_000):
    l.append(i * 2)
# Out:
# peak memory: 75.80 MiB, increment: 0.04 MiB

# %%
# %%memit l = []
# for i in range(100_000):
#     l.append(i * 2)
# Out:
# peak memory: 76.73 MiB, increment: 0.72 MiB

# %%
import tensorflow as tf

print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

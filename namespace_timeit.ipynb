# %%
import namespace as ns

# %%
# %timeit ns.test1(123_456)
# Out:
# 173 μs ± 52.2 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
# %timeit ns.test2(123_456)
# Out:
# 144 μs ± 18.3 μs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
# %timeit ns.test3(123_456)
# Out:
# 137 μs ± 3.52 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

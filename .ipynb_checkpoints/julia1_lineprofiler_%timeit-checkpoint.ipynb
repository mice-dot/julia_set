# %%
import julia1_nopil

# %%
# %timeit julia1_nopil.calc_pure_python(1000, 300)
# Out:
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 8.39852499961853 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 8.821243047714233 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 8.473869800567627 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 8.458985090255737 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 9.798500061035156 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 8.400182962417603 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 8.203802108764648 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 8.360071182250977 seconds
# 9.1 s ± 503 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
z = -0.62772 - 0.42193j

# %%
# %timeit abs(z) < 2
# Out:
# 200 ns ± 6.41 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %%
n = 1

# %%
maxiter = 300

# %%
# %timeit n < maxiter
# Out:
# 66 ns ± 10.6 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

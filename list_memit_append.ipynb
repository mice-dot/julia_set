# %%
# %load_ext memory_profiler

# %%
# %memit [i*i for i in range(100_000)]
# Out:
# peak memory: 85.32 MiB, increment: 1.83 MiB

# %%
# %timeit [i*i for i in range(100_000)]
# Out:
# 10 ms ± 783 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %timeit [i**2 for i in range(100_000)]
# Out:
# 11.5 ms ± 689 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %%memit l = []
# for i in range(100_000):
#     l.append(i * 2)
# Out:
# peak memory: 86.80 MiB, increment: 0.98 MiB

# %%
# %%timeit l = []
for i in range(100_000):
    l.append(i * 2)
# Out:
# 9.68 ms ± 3.68 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
